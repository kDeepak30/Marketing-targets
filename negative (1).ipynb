# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/dafeml.csv')
df1=pd.read_csv('/content/drive/MyDrive/dafeml.csv')
df.head()
# Out:
#   Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0         B1  2001  16.0   6.566231      2.907983        0.10         4.0
# 1         B3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2         B2  2001  41.0  15.886446      2.913410        0.40        10.0
# 3         B5  2001  83.0  30.020028      6.922304         NaN         4.0
# 4         B7  2001  15.0   8.437408      1.405998        0.03         6.0
#
#   location   Pre_Sales  Aft_sales
# 0    Urban   54.732757    60.3224
# 1    Rural   46.677897    58.7690
# 2    Rural  150.177829   172.3340
# 3    Urban  298.246340   352.3360
# 4    Rural   56.594181    59.3420

# %%
#null value -columwise
df.isna().sum()
# Out:
# Brand_name       0
# Year             0
# TV              21
# Radio           15
# Social Media    17
# Influencer      21
# Sponsering      11
# location        11
# Pre_Sales       17
# Aft_sales       17
# dtype: int64

# %%
df.columns
# Out:
# Index(['Brand_name', 'Year', 'TV', 'Radio', 'Social Media', 'Influencer',
#        'Sponsering', 'location', 'Pre_Sales', 'Aft_sales'],
#       dtype='object')

# %%
col=df.columns.values

# %%
for all in col:
  print(f"\033[1m{all}")
  print("--------------")
  print(df[all].value_counts())
# Out:
# Brand_name
# --------------
# B1     31
# B3     31
# B2     31
# B5     31
# B7     31
# B8     31
# B9     31
# B10    31
# B6     31
# B4     31
# Name: Brand_name, dtype: int64
# Year
# --------------
# 2009    42
# 2006    31
# 2001    30
# 2002    30
# 2003    30
# 2004    30
# 2010    30
# 2005    29
# 2007    29
# 2008    29
# Name: Year, dtype: int64
# TV
# --------------
# 49.0    7
# 27.0    7
# 78.0    7
# 40.0    6
# 63.0    6
#        ..
# 51.0    1
# 61.0    1
# 71.0    1
# 28.0    1
# 50.0    1
# Name: TV, Length: 87, dtype: int64
# Radio
# --------------
# 6.566231     1
# 30.498157    1
# 26.192673    1
# 27.148173    1
# 13.221237    1
#             ..
# 11.213689    1
# 24.359044    1
# 3.934783     1
# 38.415225    1
# 25.583440    1
# Name: Radio, Length: 295, dtype: int64
# Social Media
# --------------
# 2.907983    1
# 0.962942    1
# 1.230026    1
# 0.012138    1
# 4.127601    1
#            ..
# 3.797367    1
# 0.328470    1
# 7.673637    1
# 4.187834    1
# 3.870992    1
# Name: Social Media, Length: 293, dtype: int64
# Influencer
# --------------
# 0.620     17
# 0.520     13
# 0.630     12
# 0.320     12
# 0.360     12
#           ..
# 0.950      1
# 0.900      1
# 0.960      1
# 0.003      1
# 62.000     1
# Name: Influencer, Length: 85, dtype: int64
# Sponsering
# --------------
# 3.0     69
# 4.0     40
# 2.0     31
# 5.0     29
# 6.0     27
# 10.0    18
# 9.0     18
# 8.0     16
# 7.0     13
# 12.0    13
# 11.0    12
# 13.0     9
# 0.0      4
# Name: Sponsering, dtype: int64
# location
# --------------
# Urban    161
# Rural    138
# Name: location, dtype: int64
# Pre_Sales
# --------------
# 54.732757     1
# 92.357092     1
# 316.725624    1
# 45.552511     1
# 37.243272     1
#              ..
# 174.198139    1
# 72.625903     1
# 336.760633    1
# 51.442984     1
# 276.083898    1
# Name: Pre_Sales, Length: 293, dtype: int64
# Aft_sales
# --------------
# 289.8890    2
# 60.3224     1
# 314.7890    1
# 52.8857     1
# 39.7750     1
#            ..
# 132.1180    1
# 165.8350    1
# 89.8860     1
# 386.4458    1
# 289.6640    1
# Name: Aft_sales, Length: 292, dtype: int64

# %% [markdown]
# **Finding the null values in the dataset using isnull() function in Heatmap function**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def get_heatmap(df):
    #This function gives heatmap of all NaN values
    plt.figure(figsize=(6,4))
    sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
    plt.tight_layout()
    return plt.show()

get_heatmap(df)

# %% [markdown]
# **Dropping the null values using Dropna()**

# %%
df = df.dropna()
df.head()
# Out:
#   Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0         B1  2001  16.0   6.566231      2.907983        0.10         4.0
# 1         B3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2         B2  2001  41.0  15.886446      2.913410        0.40        10.0
# 4         B7  2001  15.0   8.437408      1.405998        0.03         6.0
# 5         B8  2001  29.0   9.614382      1.027163        0.02        10.0
#
#   location   Pre_Sales  Aft_sales
# 0    Urban   54.732757    60.3224
# 1    Rural   46.677897    58.7690
# 2    Rural  150.177829   172.3340
# 4    Rural   56.594181    59.3420
# 5    Urban  105.889148   111.3240

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def get_heatmap(df):
    #This function gives heatmap of all NaN values
    plt.figure(figsize=(6,4))
    sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
    plt.tight_layout()
    return plt.show()

get_heatmap(df)

# %% [markdown]
# **Checking number of null values after dropping them**

# %%
#null value -columwise
df.isna().sum()
# Out:
# Brand_name      0
# Year            0
# TV              0
# Radio           0
# Social Media    0
# Influencer      0
# Sponsering      0
# location        0
# Pre_Sales       0
# Aft_sales       0
# dtype: int64

# %%
df.head()
# Out:
#   Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0         B1  2001  16.0   6.566231      2.907983        0.10         4.0
# 1         B3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2         B2  2001  41.0  15.886446      2.913410        0.40        10.0
# 4         B7  2001  15.0   8.437408      1.405998        0.03         6.0
# 5         B8  2001  29.0   9.614382      1.027163        0.02        10.0
#
#   location   Pre_Sales  Aft_sales
# 0    Urban   54.732757    60.3224
# 1    Rural   46.677897    58.7690
# 2    Rural  150.177829   172.3340
# 4    Rural   56.594181    59.3420
# 5    Urban  105.889148   111.3240

# %%
df.Brand_name.value_counts()
# Out:
# B10    29
# B6     29
# B1     28
# B8     28
# B2     27
# B3     26
# B7     26
# B4     26
# B5     25
# B9     23
# Name: Brand_name, dtype: int64

# %% [markdown]
# ***As both "BRAND_NAME" and "Location" are in text format we are using "LABEL ENCODER" to convert into numeric ***

# %%
#data processing
from sklearn import preprocessing  

#labelencodingg
LE=preprocessing.LabelEncoder()

#fitting it to our dataset
df.Brand_name=LE.fit_transform(df.Brand_name)
df.head(5)
# Out:
#    Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0           0  2001  16.0   6.566231      2.907983        0.10         4.0
# 1           3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2           2  2001  41.0  15.886446      2.913410        0.40        10.0
# 4           7  2001  15.0   8.437408      1.405998        0.03         6.0
# 5           8  2001  29.0   9.614382      1.027163        0.02        10.0
#
#   location   Pre_Sales  Aft_sales
# 0    Urban   54.732757    60.3224
# 1    Rural   46.677897    58.7690
# 2    Rural  150.177829   172.3340
# 4    Rural   56.594181    59.3420
# 5    Urban  105.889148   111.3240

# %% [markdown]
# **We can se that the brand names are converted into numeric values**

# %%
#data processing
from sklearn import preprocessing  

#labelencodingg
LE=preprocessing.LabelEncoder()

#fitting it to our dataset
df.location=LE.fit_transform(df.location)
df.head(5)
# Out:
#    Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0           0  2001  16.0   6.566231      2.907983        0.10         4.0
# 1           3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2           2  2001  41.0  15.886446      2.913410        0.40        10.0
# 4           7  2001  15.0   8.437408      1.405998        0.03         6.0
# 5           8  2001  29.0   9.614382      1.027163        0.02        10.0
#
#    location   Pre_Sales  Aft_sales
# 0         1   54.732757    60.3224
# 1         0   46.677897    58.7690
# 2         0  150.177829   172.3340
# 4         0   56.594181    59.3420
# 5         1  105.889148   111.3240

# %% [markdown]
# **Urban and Rural are changed into numeric**

# %%
df.location.value_counts()
# Out:
# 1    141
# 0    126
# Name: location, dtype: int64

# %%
#finding the datatypes of Attributes
df.dtypes
# Out:
# Brand_name        int64
# Year              int64
# TV              float64
# Radio           float64
# Social Media    float64
# Influencer      float64
# Sponsering      float64
# location          int64
# Pre_Sales       float64
# Aft_sales       float64
# dtype: object

# %% [markdown]
# *****Visualization*****

# %%
df.location.value_counts().plot.bar()

# %% [markdown]
# It, represents the location of the advertising or marketing either it is Rural or Urban

# %%
#scatterplot
sns.scatterplot(x=df.Brand_name,y = df1.Pre_Sales)

# %% [markdown]
# This graph helps us to know the sales of a particular brand when it was not advertised

# %%
#scatterplot
sns.scatterplot(x=df.Brand_name,y = df1.Aft_sales)

# %% [markdown]
# This graph helps us to know the sales of a particular brand when it is advertised

# %%
sns.barplot(x='Brand_name',y='Pre_Sales',data=df1)

# %% [markdown]
# It shows the sales of particular brand and it's sales before marketing

# %%
sns.barplot(x='Brand_name',y='Aft_sales',data=df1)

# %% [markdown]
# It shows the sales of particular brand and it's sales after marketing

# %%
df1.Pre_Sales.plot.box()

# %%
df1.Aft_sales.plot.box()

# %%
sns.barplot(x='Brand_name',y='TV',data=df1)

# %%
sns.barplot(x='Brand_name',y='Radio',data=df1)

# %%
sns.barplot(x='Brand_name',y='Social Media',data=df1)

# %%
sns.barplot(x='Brand_name',y='Sponsering',data=df1)

# %%
sns.pairplot(df,hue = 'Pre_Sales',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %% [markdown]
# This is pairplot where the selecte dattribute is compared to all other attributes from the datasets

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title(' previous sales vs Tv') # add title 
plt.xlabel("TV")  # adds x -axis label 
plt.ylabel("Pre_Sales")  # adds y -axis label
plt.bar(df1.TV,df1.Pre_Sales)   # generates bar graph 
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
ax=sns.scatterplot(x='Pre_Sales',y = 'Aft_sales',hue="Brand_name",data = df,s=80)
ax.set_yscale('log')
ax.set_yticks([10,50,100,120,180,210,290,440,500])
# ax.set_yticklabels([0.03, 0.1, 0.3, 1, 3, 10, 30, 100, 300, 1000])
ax.yaxis.set_major_formatter(FormatStrFormatter('%g'))
plt.show()

# %%
df1.hist(bins=50,figsize=(20,15))
plt.show()

# %% [markdown]
# here each groups numbers into ranges

# %% [markdown]
# Aft_sales as dependent variable

# %%
df.head()
# Out:
#    Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0           0  2001  16.0   6.566231      2.907983        0.10         4.0
# 1           3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2           2  2001  41.0  15.886446      2.913410        0.40        10.0
# 4           7  2001  15.0   8.437408      1.405998        0.03         6.0
# 5           8  2001  29.0   9.614382      1.027163        0.02        10.0
#
#    location   Pre_Sales  Aft_sales
# 0         1   54.732757    60.3224
# 1         0   46.677897    58.7690
# 2         0  150.177829   172.3340
# 4         0   56.594181    59.3420
# 5         1  105.889148   111.3240

# %%
X=df.iloc[:,:-1].values
Y=df.iloc[:,1:].values

# %%
import numpy as np
train_x=np.array(df[['Brand_name','Year','TV','Radio','Social Media','Influencer','Sponsering','location','Pre_Sales']])
train_y=np.array(df[['Aft_sales']])

# %%
print(train_x)
# Out:
# [[0.00000000e+00 2.00100000e+03 1.60000000e+01 ... 4.00000000e+00
#   1.00000000e+00 5.47327571e+01]
#  [3.00000000e+00 2.00100000e+03 1.30000000e+01 ... 2.00000000e+00
#   0.00000000e+00 4.66778970e+01]
#  [2.00000000e+00 2.00100000e+03 4.10000000e+01 ... 1.00000000e+01
#   0.00000000e+00 1.50177829e+02]
#  ...
#  [9.00000000e+00 2.00900000e+03 7.70000000e+01 ... 3.00000000e+00
#   0.00000000e+00 2.75388673e+02]
#  [1.00000000e+00 2.00900000e+03 2.70000000e+01 ... 3.00000000e+00
#   0.00000000e+00 9.33517594e+01]
#  [6.00000000e+00 2.00900000e+03 7.70000000e+01 ... 6.00000000e+00
#   0.00000000e+00 2.76083898e+02]]

# %%
print(train_y)
# Out:
# [[  60.3224 ]
#  [  58.769  ]
#  [ 172.334  ]
#  [  59.342  ]
#  [ 111.324  ]
#  [ 132.331  ]
#  [ 323.443  ]
#  [  43.441  ]
#  [ 259.228  ]
#  [ 148.442  ]
#  [ 132.245  ]
#  [ 222.231  ]
#  [ 117.99   ]
#  [ 432.442  ]
#  [ 342.241  ]
#  [ 154.456  ]
#  [ 142.22   ]
#  [ 332.321  ]
#  [ 212.227  ]
#  [ 112.165  ]
#  [  79.332  ]
#  [ 150.999  ]
#  [ 246.332  ]
#  [ 320.465  ]
#  [  52.331  ]
#  [ 288.33   ]
#  [ 162.332  ]
#  [ 170.117  ]
#  [ 169.669  ]
#  [ 289.889  ]
#  [ 333.332  ]
#  [ 241.441  ]
#  [ 163.663  ]
#  [ 287.887  ]
#  [ 253.324  ]
#  [ 448.567  ]
#  [ 112.115  ]
#  [  64.66453]
#  [ 132.576  ]
#  [ 132.334  ]
#  [ 133.56987]
#  [ 132.11243]
#  [ 352.117  ]
#  [ 332.3214 ]
#  [ 289.453  ]
#  [ 179.114  ]
#  [  42.4421 ]
#  [ 241.521  ]
#  [  59.765  ]
#  [  83.662  ]
#  [  79.753  ]
#  [ 296.553  ]
#  [ 332.632  ]
#  [ 224.33786]
#  [ 163.876  ]
#  [ 254.445  ]
#  [ 312.542  ]
#  [  68.664  ]
#  [ 352.332  ]
#  [ 389.553  ]
#  [  54.3352 ]
#  [ 253.553  ]
#  [ 259.77567]
#  [ 287.5564 ]
#  [ 312.331  ]
#  [ 169.34567]
#  [ 212.221  ]
#  [ 386.786  ]
#  [ 174.7735 ]
#  [  67.667  ]
#  [ 289.889  ]
#  [  82.354  ]
#  [ 368.662  ]
#  [ 153.3367 ]
#  [  46.35487]
#  [ 387.5576 ]
#  [ 389.5462 ]
#  [ 173.5643 ]
#  [ 325.6597 ]
#  [ 356.553  ]
#  [ 153.776  ]
#  [ 142.5532 ]
#  [ 112.321  ]
#  [ 287.4435 ]
#  [  76.7768 ]
#  [ 386.4458 ]
#  [  89.886  ]
#  [ 165.835  ]
#  [ 132.118  ]
#  [ 165.437  ]
#  [ 154.4435 ]
#  [ 145.7324 ]
#  [ 164.664  ]
#  [ 150.6654 ]
#  [ 350.665  ]
#  [ 321.5543 ]
#  [ 276.6657 ]
#  [ 326.553  ]
#  [ 353.654  ]
#  [ 254.77654]
#  [ 121.2242 ]
#  [  71.1876 ]
#  [  89.5523 ]
#  [ 212.6654 ]
#  [ 158.99564]
#  [ 280.885  ]
#  [ 193.996  ]
#  [ 280.664  ]
#  [ 261.553  ]
#  [ 370.537  ]
#  [ 163.997  ]
#  [ 312.6745 ]
#  [ 143.334  ]
#  [ 111.132  ]
#  [ 189.4435 ]
#  [  99.993  ]
#  [ 119.991  ]
#  [ 398.8897 ]
#  [  88.897  ]
#  [ 153.006  ]
#  [ 165.644  ]
#  [  53.336  ]
#  [ 167.776  ]
#  [ 221.436  ]
#  [ 342.3374 ]
#  [ 260.775  ]
#  [ 245.87   ]
#  [ 358.876  ]
#  [ 356.7786 ]
#  [ 287.776  ]
#  [ 265.78786]
#  [ 132.8897 ]
#  [ 212.6534 ]
#  [ 112.6544 ]
#  [ 258.8756 ]
#  [ 163.6534 ]
#  [  69.886  ]
#  [ 312.54398]
#  [ 243.665  ]
#  [  99.0634 ]
#  [ 165.879  ]
#  [ 254.664  ]
#  [ 193.66456]
#  [ 365.     ]
#  [ 184.775  ]
#  [  46.6675 ]
#  [  89.6654 ]
#  [ 121.1178 ]
#  [ 390.75654]
#  [ 143.9976 ]
#  [ 156.8753 ]
#  [ 162.8864 ]
#  [ 189.8744 ]
#  [ 287.7734 ]
#  [ 184.873  ]
#  [ 210.553  ]
#  [ 289.115  ]
#  [ 218.55623]
#  [ 298.654  ]
#  [ 132.8863 ]
#  [ 349.664  ]
#  [ 267.543  ]
#  [ 354.6643 ]
#  [ 256.6635 ]
#  [ 331.435  ]
#  [ 233.995  ]
#  [ 143.5543 ]
#  [ 375.7753 ]
#  [ 352.885  ]
#  [ 132.77534]
#  [ 289.995  ]
#  [ 163.5376 ]
#  [ 298.886  ]
#  [  96.6643 ]
#  [  68.753  ]
#  [  52.865  ]
#  [  39.775  ]
#  [  52.8857 ]
#  [ 165.964  ]
#  [ 331.885  ]
#  [ 278.775  ]
#  [ 189.996  ]
#  [ 302.5523 ]
#  [ 142.5263 ]
#  [ 332.5343 ]
#  [ 391.65638]
#  [ 358.7734 ]
#  [ 103.5527 ]
#  [ 198.4356 ]
#  [ 261.6632 ]
#  [ 291.7734 ]
#  [ 221.8654 ]
#  [ 163.885  ]
#  [ 301.7754 ]
#  [ 163.995  ]
#  [  89.775  ]
#  [ 298.99564]
#  [  63.88534]
#  [ 287.8854 ]
#  [ 251.66324]
#  [ 174.7734 ]
#  [ 121.553  ]
#  [  86.7745 ]
#  [  72.6634 ]
#  [ 146.6634 ]
#  [ 136.9945 ]
#  [ 243.7734 ]
#  [ 298.734  ]
#  [ 341.4231 ]
#  [ 165.6342 ]
#  [  61.63442]
#  [ 152.7342 ]
#  [ 221.5342 ]
#  [ 189.6342 ]
#  [ 265.9964 ]
#  [ 218.6624 ]
#  [ 333.5361 ]
#  [2341.634  ]
#  [ 104.63412]
#  [  96.634  ]
#  [ 368.734  ]
#  [  52.67743]
#  [ 186.6342 ]
#  [ 143.6634 ]
#  [  72.8864 ]
#  [ 168.8854 ]
#  [ 289.667  ]
#  [ 316.6643 ]
#  [ 240.6643 ]
#  [ 246.0012 ]
#  [ 169.8865 ]
#  [ 187.6645 ]
#  [ 356.99876]
#  [ 233.645  ]
#  [ 235.8664 ]
#  [ 286.084  ]
#  [  59.996  ]
#  [ 276.964  ]
#  [ 290.7745 ]
#  [  45.7543 ]
#  [ 330.88455]
#  [ 319.7764 ]
#  [ 165.8845 ]
#  [ 336.73456]
#  [ 212.6645 ]
#  [  65.88756]
#  [ 353.774  ]
#  [  98.998  ]
#  [ 343.6645 ]
#  [ 212.5534 ]
#  [ 111.646  ]
#  [  52.645  ]
#  [ 313.553  ]
#  [ 242.543  ]
#  [  73.8645 ]
#  [ 300.756  ]
#  [ 230.6645 ]
#  [ 241.88564]
#  [ 146.8867 ]
#  [  87.885  ]
#  [ 189.6634 ]
#  [ 231.6634 ]
#  [  98.886  ]
#  [ 123.7745 ]
#  [ 302.8864 ]
#  [ 101.976  ]
#  [ 289.664  ]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
df.isnull().any()
# Out:
# Brand_name      False
# Year            False
# TV              False
# Radio           False
# Social Media    False
# Influencer      False
# Sponsering      False
# location        False
# Pre_Sales       False
# Aft_sales       False
# dtype: bool

# %%
#training the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#testing the model
y_pred = model.predict(x_test)

# %%
#Finding the accuracy - How Accurate the model is?
import numpy as np
print("Mean Square Error(MSE): %.2f" % np.mean(((y_pred - y_test)** 2)**0.5))
# Out:
# Mean Square Error(MSE): 2.84

# %%
print("Predicted value for training data:",model.score(x_train,y_train))
print("Training accuracy:",model.score(x_train,y_train)*100)
# Out:
# Predicted value for training data: 0.9264212351585284
# Training accuracy: 92.64212351585283

# %%
print("Predicted value for testing data:",model.score(x_test,y_test))
print("Testing accuracy:",model.score(x_test,y_test)*100)
# Out:
# Predicted value for testing data: 0.9574148222675143
# Testing accuracy: 95.74148222675143

# %%
accuracy=model.score(X,Y)*100
print(accuracy)
# Out:
# 92.86935993439064

# %%
df.head()
# Out:
#    Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0           0  2001  16.0   6.566231      2.907983        0.10         4.0
# 1           3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2           2  2001  41.0  15.886446      2.913410        0.40        10.0
# 4           7  2001  15.0   8.437408      1.405998        0.03         6.0
# 5           8  2001  29.0   9.614382      1.027163        0.02        10.0
#
#    location   Pre_Sales  Aft_sales
# 0         1   54.732757    60.3224
# 1         0   46.677897    58.7690
# 2         0  150.177829   172.3340
# 4         0   56.594181    59.3420
# 5         1  105.889148   111.3240

# %% [markdown]
# tv as dependent variable

# %%
import numpy as np
Xtv=np.array(df[['Brand_name','Year','Radio','Social Media','Influencer','Sponsering','location','Pre_Sales','Aft_sales']])
Ytv=np.array(df[['TV']])

# %%
print(Xtv)
# Out:
# [[0.00000000e+00 2.00100000e+03 6.56623079e+00 ... 1.00000000e+00
#   5.47327571e+01 6.03224000e+01]
#  [3.00000000e+00 2.00100000e+03 9.23776457e+00 ... 0.00000000e+00
#   4.66778970e+01 5.87690000e+01]
#  [2.00000000e+00 2.00100000e+03 1.58864460e+01 ... 0.00000000e+00
#   1.50177829e+02 1.72334000e+02]
#  ...
#  [9.00000000e+00 2.00900000e+03 2.10319654e+01 ... 0.00000000e+00
#   2.75388673e+02 3.02886400e+02]
#  [1.00000000e+00 2.00900000e+03 9.23584566e+00 ... 0.00000000e+00
#   9.33517594e+01 1.01976000e+02]
#  [6.00000000e+00 2.00900000e+03 2.55834396e+01 ... 0.00000000e+00
#   2.76083898e+02 2.89664000e+02]]

# %%
print(Ytv)
# Out:
# [[ 16.]
#  [ 13.]
#  [ 41.]
#  [ 15.]
#  [ 29.]
#  [ 31.]
#  [ 76.]
#  [ 13.]
#  [ 62.]
#  [ 42.]
#  [ 36.]
#  [ 60.]
#  [ 25.]
#  [100.]
#  [ 92.]
#  [ 46.]
#  [ 37.]
#  [ 99.]
#  [ 54.]
#  [ 27.]
#  [ 21.]
#  [ 40.]
#  [ 67.]
#  [ 90.]
#  [ 12.]
#  [ 81.]
#  [ 43.]
#  [ 47.]
#  [ 43.]
#  [ 75.]
#  [ 79.]
#  [ 65.]
#  [ 43.]
#  [ 82.]
#  [ 68.]
#  [ 98.]
#  [ 26.]
#  [ 10.]
#  [ 32.]
#  [ 29.]
#  [ 32.]
#  [ 29.]
#  [ 91.]
#  [ 83.]
#  [ 72.]
#  [ 47.]
#  [ 10.]
#  [ 49.]
#  [ 14.]
#  [ 20.]
#  [ 17.]
#  [ 68.]
#  [ 91.]
#  [ 52.]
#  [ 41.]
#  [ 65.]
#  [ 82.]
#  [ 14.]
#  [ 84.]
#  [ 99.]
#  [ 15.]
#  [ 64.]
#  [ 70.]
#  [ 77.]
#  [ 81.]
#  [ 46.]
#  [ 56.]
#  [ 98.]
#  [ 47.]
#  [ 18.]
#  [ 77.]
#  [ 22.]
#  [ 99.]
#  [ 36.]
#  [ 12.]
#  [ 94.]
#  [ 97.]
#  [ 44.]
#  [ 86.]
#  [ 93.]
#  [ 30.]
#  [ 32.]
#  [ 29.]
#  [ 72.]
#  [ 14.]
#  [ 95.]
#  [ 20.]
#  [ 49.]
#  [ 29.]
#  [ 39.]
#  [ 87.]
#  [ 38.]
#  [ 43.]
#  [ 30.]
#  [ 93.]
#  [ 86.]
#  [ 63.]
#  [ 93.]
#  [ 94.]
#  [ 63.]
#  [ 30.]
#  [ 18.]
#  [ 24.]
#  [ 56.]
#  [ 40.]
#  [ 74.]
#  [ 52.]
#  [ 74.]
#  [ 70.]
#  [ 99.]
#  [ 42.]
#  [ 85.]
#  [ 38.]
#  [ 30.]
#  [ 49.]
#  [ 27.]
#  [ 30.]
#  [100.]
#  [ 21.]
#  [ 38.]
#  [ 39.]
#  [ 14.]
#  [ 40.]
#  [ 33.]
#  [ 88.]
#  [ 67.]
#  [ 65.]
#  [ 95.]
#  [ 95.]
#  [ 77.]
#  [ 70.]
#  [ 34.]
#  [ 59.]
#  [ 30.]
#  [ 68.]
#  [ 43.]
#  [ 18.]
#  [ 84.]
#  [ 61.]
#  [ 24.]
#  [ 41.]
#  [ 67.]
#  [ 51.]
#  [100.]
#  [ 44.]
#  [ 10.]
#  [ 21.]
#  [ 32.]
#  [ 98.]
#  [ 39.]
#  [ 40.]
#  [ 44.]
#  [ 49.]
#  [ 78.]
#  [ 49.]
#  [ 55.]
#  [ 73.]
#  [ 58.]
#  [ 82.]
#  [ 27.]
#  [ 94.]
#  [ 69.]
#  [ 94.]
#  [ 70.]
#  [ 88.]
#  [ 64.]
#  [ 39.]
#  [ 99.]
#  [ 94.]
#  [ 36.]
#  [ 78.]
#  [ 44.]
#  [ 79.]
#  [ 26.]
#  [ 17.]
#  [ 13.]
#  [ 12.]
#  [ 11.]
#  [ 39.]
#  [ 86.]
#  [ 76.]
#  [ 33.]
#  [ 83.]
#  [ 37.]
#  [ 92.]
#  [100.]
#  [ 94.]
#  [ 27.]
#  [ 53.]
#  [ 73.]
#  [ 78.]
#  [ 59.]
#  [ 44.]
#  [ 82.]
#  [ 47.]
#  [ 22.]
#  [ 78.]
#  [ 15.]
#  [ 78.]
#  [ 63.]
#  [ 45.]
#  [ 31.]
#  [ 23.]
#  [ 19.]
#  [ 40.]
#  [ 35.]
#  [ 63.]
#  [ 78.]
#  [ 91.]
#  [ 44.]
#  [ 16.]
#  [ 40.]
#  [ 60.]
#  [ 49.]
#  [ 71.]
#  [ 59.]
#  [ 92.]
#  [ 60.]
#  [ 28.]
#  [ 29.]
#  [ 97.]
#  [ 11.]
#  [ 49.]
#  [ 38.]
#  [ 18.]
#  [ 42.]
#  [ 76.]
#  [ 86.]
#  [ 70.]
#  [ 69.]
#  [ 47.]
#  [ 46.]
#  [ 98.]
#  [ 63.]
#  [ 66.]
#  [ 76.]
#  [ 12.]
#  [ 75.]
#  [ 85.]
#  [ 12.]
#  [ 90.]
#  [ 88.]
#  [ 35.]
#  [ 89.]
#  [ 54.]
#  [ 16.]
#  [ 98.]
#  [ 23.]
#  [ 93.]
#  [ 52.]
#  [ 27.]
#  [ 13.]
#  [ 83.]
#  [ 66.]
#  [ 19.]
#  [ 85.]
#  [ 63.]
#  [ 62.]
#  [ 45.]
#  [ 23.]
#  [ 50.]
#  [ 60.]
#  [ 25.]
#  [ 31.]
#  [ 77.]
#  [ 27.]
#  [ 77.]]

# %%
from sklearn.model_selection import train_test_split
x_traintv,x_testtv,y_traintv,y_testtv=train_test_split(Xtv,Ytv,test_size=0.2,random_state=0)

# %%
df.isnull().any()
# Out:
# Brand_name      False
# Year            False
# TV              False
# Radio           False
# Social Media    False
# Influencer      False
# Sponsering      False
# location        False
# Pre_Sales       False
# Aft_sales       False
# dtype: bool

# %%
model.fit(x_traintv, y_traintv)
# Out:
# LinearRegression()

# %%
#testing the model
y_predtv = model.predict(x_testtv)

# %%
#Finding the accuracy - How Accurate the model is?
import numpy as np
print("Mean Square Error(MSE): %.2f" % np.mean(((y_predtv - y_testtv)** 2)**0.5))
# Out:
# Mean Square Error(MSE): 0.80

# %%
print("Predicted value for training data:",model.score(x_traintv,y_traintv))
print("Training accuracy:",model.score(x_traintv,y_traintv)*100)
# Out:
# Predicted value for training data: 0.9990974543535829
# Training accuracy: 99.90974543535829

# %%
print("Predicted value for testing data:",model.score(x_testtv,y_testtv))
print("Testing accuracy:",model.score(x_testtv,y_testtv)*100)
# Out:
# Predicted value for testing data: 0.9970701640528364
# Testing accuracy: 99.70701640528364

# %%
accuracytv=model.score(Xtv,Ytv)*100
print(accuracytv)
# Out:
# 99.87317937140618

# %% [markdown]
# radio as dependent variable

# %%
df.head()
# Out:
#    Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0           0  2001  16.0   6.566231      2.907983        0.10         4.0
# 1           3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2           2  2001  41.0  15.886446      2.913410        0.40        10.0
# 4           7  2001  15.0   8.437408      1.405998        0.03         6.0
# 5           8  2001  29.0   9.614382      1.027163        0.02        10.0
#
#    location   Pre_Sales  Aft_sales
# 0         1   54.732757    60.3224
# 1         0   46.677897    58.7690
# 2         0  150.177829   172.3340
# 4         0   56.594181    59.3420
# 5         1  105.889148   111.3240

# %%
Xrd=np.array(df[['Brand_name','Year','TV','Social Media','Influencer','Sponsering','location','Pre_Sales','Aft_sales']])
Yrd=np.array(df[['Radio']])

# %%
print(Xrd)
# Out:
# [[0.00000000e+00 2.00100000e+03 1.60000000e+01 ... 1.00000000e+00
#   5.47327571e+01 6.03224000e+01]
#  [3.00000000e+00 2.00100000e+03 1.30000000e+01 ... 0.00000000e+00
#   4.66778970e+01 5.87690000e+01]
#  [2.00000000e+00 2.00100000e+03 4.10000000e+01 ... 0.00000000e+00
#   1.50177829e+02 1.72334000e+02]
#  ...
#  [9.00000000e+00 2.00900000e+03 7.70000000e+01 ... 0.00000000e+00
#   2.75388673e+02 3.02886400e+02]
#  [1.00000000e+00 2.00900000e+03 2.70000000e+01 ... 0.00000000e+00
#   9.33517594e+01 1.01976000e+02]
#  [6.00000000e+00 2.00900000e+03 7.70000000e+01 ... 0.00000000e+00
#   2.76083898e+02 2.89664000e+02]]

# %%
print(Yrd)
# Out:
# [[ 6.56623079]
#  [ 9.23776457]
#  [15.88644602]
#  [ 8.43740768]
#  [ 9.61438204]
#  [17.35504181]
#  [24.64889821]
#  [ 0.43112782]
#  [24.34518879]
#  [15.8073374 ]
#  [ 3.90019598]
#  [22.35372075]
#  [ 9.90584265]
#  [36.11609149]
#  [40.73698967]
#  [12.69509229]
#  [ 2.82897246]
#  [37.26381865]
#  [27.807614  ]
#  [ 7.28008896]
#  [ 9.28268517]
#  [13.05041081]
#  [24.13761593]
#  [29.02101661]
#  [ 3.56766071]
#  [27.33577511]
#  [16.34871104]
#  [17.37652562]
#  [18.23019243]
#  [23.62623841]
#  [23.51057067]
#  [24.56354623]
#  [12.84212842]
#  [27.64758545]
#  [21.63920124]
#  [37.57095206]
#  [10.59953251]
#  [ 6.14524826]
#  [ 0.62761877]
#  [ 8.85209441]
#  [11.52414895]
#  [14.4341063 ]
#  [40.10852728]
#  [34.28141179]
#  [23.92269582]
#  [24.16913194]
#  [ 3.45586838]
#  [10.06762616]
#  [ 5.19785619]
#  [10.75005058]
#  [10.44745162]
#  [29.8927411 ]
#  [25.04555745]
#  [17.11323977]
#  [ 3.92154002]
#  [11.65648785]
#  [31.60769079]
#  [18.64944183]
#  [31.26640836]
#  [30.14056912]
#  [ 2.23429341]
#  [24.69852188]
#  [15.2477262 ]
#  [26.82235002]
#  [20.39194685]
#  [17.79013454]
#  [25.27608704]
#  [33.05515873]
#  [18.2339617 ]
#  [ 8.80870277]
#  [22.9553127 ]
#  [ 6.04172579]
#  [37.7178052 ]
#  [ 9.09677989]
#  [ 1.64819798]
#  [47.11629339]
#  [39.23230636]
#  [16.91203429]
#  [31.52189727]
#  [33.05945096]
#  [10.64510759]
#  [ 0.75806666]
#  [ 2.17259634]
#  [25.40659637]
#  [ 8.00126585]
#  [38.41522497]
#  [ 3.93478349]
#  [24.35904434]
#  [11.21368878]
#  [13.18725635]
#  [33.70789822]
#  [ 9.43771171]
#  [ 9.72673605]
#  [ 8.42199473]
#  [19.95638677]
#  [25.26070742]
#  [26.03598627]
#  [28.03820883]
#  [32.14620508]
#  [21.84654391]
#  [17.46901907]
#  [ 7.29195552]
#  [ 3.42602122]
#  [14.88018119]
#  [17.42884965]
#  [29.56295098]
#  [14.56589504]
#  [20.22086793]
#  [15.3541893 ]
#  [33.87824351]
#  [15.21523612]
#  [31.79693826]
#  [ 8.87227468]
#  [15.43267247]
#  [21.03218038]
#  [ 6.44750816]
#  [ 4.56131216]
#  [36.57380821]
#  [ 1.38031107]
#  [18.90360911]
#  [ 9.72274602]
#  [ 4.82827979]
#  [18.378401  ]
#  [17.44947546]
#  [26.00963987]
#  [28.48182095]
#  [20.06155575]
#  [30.73728576]
#  [36.42230623]
#  [31.6532001 ]
#  [21.43851856]
#  [16.19365273]
#  [13.45217597]
#  [12.1555835 ]
#  [22.38968684]
#  [ 8.57386453]
#  [ 8.47713529]
#  [33.9556193 ]
#  [28.38518716]
#  [11.88643795]
#  [ 8.71524832]
#  [18.30464111]
#  [24.00692574]
#  [36.73413489]
#  [18.94795499]
#  [ 0.75856941]
#  [ 1.39737111]
#  [ 5.47195557]
#  [31.36391464]
#  [ 4.85612301]
#  [19.63906306]
#  [19.01537456]
#  [24.87104934]
#  [30.11726533]
#  [20.42365468]
#  [22.37478299]
#  [22.86737608]
#  [17.39877506]
#  [23.43478708]
#  [10.33353047]
#  [29.34460985]
#  [23.29045109]
#  [37.09705521]
#  [23.80856837]
#  [27.46149343]
#  [23.08148805]
#  [11.78254265]
#  [37.73241144]
#  [30.49815694]
#  [ 8.84011251]
#  [26.40676494]
#  [ 6.31317339]
#  [27.88320654]
#  [15.26673306]
#  [ 8.19793247]
#  [ 8.07750159]
#  [ 3.55657656]
#  [ 3.78525465]
#  [13.22123736]
#  [27.14817277]
#  [26.19267329]
#  [13.36586735]
#  [28.40915338]
#  [10.25291621]
#  [16.70376892]
#  [32.920194  ]
#  [30.37270595]
#  [ 3.43882449]
#  [19.04450325]
#  [28.4645976 ]
#  [26.39407008]
#  [25.68728652]
#  [15.72633981]
#  [33.67469531]
#  [14.16232438]
#  [ 3.59847428]
#  [24.89028294]
#  [ 9.80964726]
#  [36.13477932]
#  [19.10204333]
#  [12.22739961]
#  [ 8.84392465]
#  [ 2.20175245]
#  [ 4.89441073]
#  [11.90789251]
#  [ 5.39262429]
#  [20.77468172]
#  [23.80959139]
#  [22.27671374]
#  [16.60931402]
#  [12.25135762]
#  [12.7084063 ]
#  [21.43888957]
#  [16.31903668]
#  [26.02394936]
#  [21.27291211]
#  [33.29585958]
#  [19.01558716]
#  [10.93200857]
#  [ 9.19703233]
#  [31.70701011]
#  [ 9.39883922]
#  [13.76198317]
#  [ 4.33884304]
#  [12.38447814]
#  [10.01903472]
#  [32.31926372]
#  [29.91962703]
#  [30.47388738]
#  [24.36246064]
#  [14.59516994]
#  [17.87483166]
#  [33.5556744 ]
#  [18.31721305]
#  [15.81007671]
#  [21.43025018]
#  [12.84827976]
#  [38.27143199]
#  [25.24181707]
#  [ 3.18866831]
#  [33.5117751 ]
#  [35.4551909 ]
#  [18.81472652]
#  [26.11806108]
#  [22.45001505]
#  [ 1.0950547 ]
#  [32.07909439]
#  [ 7.98978736]
#  [33.74742661]
#  [17.45288044]
#  [ 8.3013931 ]
#  [ 5.35882172]
#  [21.93601248]
#  [21.57823348]
#  [ 7.78950723]
#  [23.77346122]
#  [19.71906624]
#  [25.07908112]
#  [15.53732896]
#  [ 6.62163532]
#  [11.36398701]
#  [19.49995648]
#  [13.00455149]
#  [12.22596591]
#  [21.03196536]
#  [ 9.23584566]
#  [25.58343965]]

# %%
from sklearn.model_selection import train_test_split
x_trainrd,x_testrd,y_trainrd,y_testrd=train_test_split(Xrd,Yrd,test_size=0.2,random_state=0)

# %%
df.isnull().any()
# Out:
# Brand_name      False
# Year            False
# TV              False
# Radio           False
# Social Media    False
# Influencer      False
# Sponsering      False
# location        False
# Pre_Sales       False
# Aft_sales       False
# dtype: bool

# %%
model.fit(x_trainrd, y_trainrd)
# Out:
# LinearRegression()

# %%
#testing the model
y_predrd = model.predict(x_testrd)

# %%
#Finding the accuracy - How Accurate the model is?
import numpy as np
print("Mean Square Error(MSE): %.2f" % np.mean(((y_predrd - y_testrd)** 2)**0.5))
# Out:
# Mean Square Error(MSE): 5.67

# %%
print("Predicted value for training data:",model.score(x_trainrd,y_trainrd))
print("Training accuracy:",model.score(x_trainrd,y_trainrd)*100)
# Out:
# Predicted value for training data: 0.8484109928910306
# Training accuracy: 84.84109928910306

# %%
print("Predicted value for testing data:",model.score(x_testrd,y_testrd))
print("Testing accuracy:",model.score(x_testrd,y_testrd)*100)
# Out:
# Predicted value for testing data: -2.497126547573977
# Testing accuracy: -249.7126547573977

# %% [markdown]
# social media as dependent variable

# %%
df.head()
# Out:
#    Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0           0  2001  16.0   6.566231      2.907983        0.10         4.0
# 1           3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2           2  2001  41.0  15.886446      2.913410        0.40        10.0
# 4           7  2001  15.0   8.437408      1.405998        0.03         6.0
# 5           8  2001  29.0   9.614382      1.027163        0.02        10.0
#
#    location   Pre_Sales  Aft_sales
# 0         1   54.732757    60.3224
# 1         0   46.677897    58.7690
# 2         0  150.177829   172.3340
# 4         0   56.594181    59.3420
# 5         1  105.889148   111.3240

# %%
Xsm=np.array(df[['Brand_name','Year','TV','Radio','Influencer','Sponsering','location','Pre_Sales','Aft_sales']])
Ysm=np.array(df[['Social Media']])

# %%
print(Xsm)
# Out:
# [[0.00000000e+00 2.00100000e+03 1.60000000e+01 ... 1.00000000e+00
#   5.47327571e+01 6.03224000e+01]
#  [3.00000000e+00 2.00100000e+03 1.30000000e+01 ... 0.00000000e+00
#   4.66778970e+01 5.87690000e+01]
#  [2.00000000e+00 2.00100000e+03 4.10000000e+01 ... 0.00000000e+00
#   1.50177829e+02 1.72334000e+02]
#  ...
#  [9.00000000e+00 2.00900000e+03 7.70000000e+01 ... 0.00000000e+00
#   2.75388673e+02 3.02886400e+02]
#  [1.00000000e+00 2.00900000e+03 2.70000000e+01 ... 0.00000000e+00
#   9.33517594e+01 1.01976000e+02]
#  [6.00000000e+00 2.00900000e+03 7.70000000e+01 ... 0.00000000e+00
#   2.76083898e+02 2.89664000e+02]]

# %%
print(Ysm)
# Out:
# [[2.90798277e+00]
#  [2.40956720e+00]
#  [2.91341018e+00]
#  [1.40599815e+00]
#  [1.02716349e+00]
#  [2.28985493e+00]
#  [7.13011596e+00]
#  [2.22942302e+00]
#  [5.15148317e+00]
#  [3.19492464e+00]
#  [6.04017950e-02]
#  [9.40801841e-01]
#  [1.85322490e+00]
#  [3.67429598e+00]
#  [4.63656390e+00]
#  [3.88458384e+00]
#  [4.55670124e+00]
#  [6.88653481e+00]
#  [4.06078197e+00]
#  [2.17947801e+00]
#  [3.05575838e+00]
#  [1.97118480e+00]
#  [5.57309335e+00]
#  [6.43199529e+00]
#  [3.55831136e+00]
#  [5.26365038e+00]
#  [2.81401346e+00]
#  [1.90504027e+00]
#  [4.07929302e+00]
#  [6.19976916e+00]
#  [2.18892606e+00]
#  [3.41966808e+00]
#  [2.59369732e+00]
#  [5.61122184e+00]
#  [3.22364770e+00]
#  [8.52960437e+00]
#  [6.79275349e-01]
#  [1.59111647e+00]
#  [2.67607517e+00]
#  [4.14943490e-02]
#  [2.56679136e+00]
#  [4.63277331e-01]
#  [7.23617047e+00]
#  [8.69748740e+00]
#  [3.37380966e+00]
#  [2.08791026e+00]
#  [2.40011807e+00]
#  [1.72966741e+00]
#  [4.13965989e-01]
#  [2.44217381e+00]
#  [3.35610642e+00]
#  [6.09674374e+00]
#  [6.10936969e+00]
#  [2.63864242e+00]
#  [2.52785059e+00]
#  [3.58471532e-01]
#  [3.95244811e+00]
#  [4.52992708e+00]
#  [8.08073156e+00]
#  [6.54615802e+00]
#  [1.07771826e+00]
#  [6.74138276e+00]
#  [4.58770338e+00]
#  [5.51418722e+00]
#  [3.21225026e+00]
#  [4.11763199e+00]
#  [3.23926521e+00]
#  [6.06345772e+00]
#  [8.27545346e-01]
#  [2.41418629e+00]
#  [2.64250482e+00]
#  [2.13663236e+00]
#  [3.59008638e+00]
#  [3.81883449e+00]
#  [1.30572513e+00]
#  [9.32295780e+00]
#  [3.69866108e+00]
#  [4.03466018e+00]
#  [6.39828365e+00]
#  [5.78929841e+00]
#  [1.91551712e+00]
#  [2.35920024e+00]
#  [4.20832450e+00]
#  [3.21545540e+00]
#  [4.18783431e+00]
#  [7.67363655e+00]
#  [3.28469804e-01]
#  [3.79736729e+00]
#  [5.58836580e-01]
#  [2.76635227e+00]
#  [3.32727272e+00]
#  [4.37758781e+00]
#  [3.37998227e-01]
#  [3.27948059e+00]
#  [2.26140631e+00]
#  [6.76566389e+00]
#  [3.29081689e+00]
#  [2.92428184e+00]
#  [4.61092529e+00]
#  [2.64241023e+00]
#  [4.33763418e+00]
#  [2.31795907e+00]
#  [3.17676000e-03]
#  [2.36755682e+00]
#  [3.30670615e+00]
#  [2.06071970e+00]
#  [1.99821840e+00]
#  [4.54090452e+00]
#  [1.04936956e+00]
#  [8.09161099e+00]
#  [1.50144596e+00]
#  [1.60000000e-01]
#  [1.60521340e+00]
#  [3.98657020e+00]
#  [5.08701696e+00]
#  [1.41563825e+00]
#  [1.65275962e+00]
#  [5.27315617e+00]
#  [5.28668096e+00]
#  [4.88999345e+00]
#  [9.03060425e-01]
#  [2.86038590e-01]
#  [1.32008011e+00]
#  [8.87761603e-01]
#  [1.49560076e+00]
#  [1.52080389e+00]
#  [3.52927420e+00]
#  [8.98023438e+00]
#  [9.99747220e+00]
#  [7.77697840e+00]
#  [5.70810498e+00]
#  [7.92203039e-01]
#  [1.50308216e+00]
#  [9.32529328e-01]
#  [1.50610578e+00]
#  [3.29836216e+00]
#  [6.08817354e-01]
#  [4.47987109e+00]
#  [6.15770457e+00]
#  [1.55820907e+00]
#  [1.81466489e-01]
#  [4.89517190e+00]
#  [4.15202201e+00]
#  [7.35971428e+00]
#  [2.22981382e+00]
#  [5.27880863e-01]
#  [1.44459113e+00]
#  [6.72964457e-01]
#  [5.65755044e+00]
#  [8.74163256e-01]
#  [7.95725948e-01]
#  [6.54330695e+00]
#  [5.03628143e+00]
#  [3.35779409e+00]
#  [4.34677736e+00]
#  [5.06657786e+00]
#  [9.68984226e-01]
#  [4.00744715e+00]
#  [5.91486613e+00]
#  [1.13012251e+00]
#  [3.43648101e+00]
#  [5.67168608e+00]
#  [7.59629045e+00]
#  [3.76660304e+00]
#  [1.52406207e+00]
#  [3.05629813e+00]
#  [2.95672684e+00]
#  [7.72405273e+00]
#  [8.82331193e+00]
#  [9.62941668e-01]
#  [2.47510162e+00]
#  [1.31002786e+00]
#  [7.46794169e+00]
#  [2.20587986e+00]
#  [2.11987225e+00]
#  [1.32301470e-02]
#  [3.60014914e-01]
#  [1.56964457e+00]
#  [3.66056613e+00]
#  [4.40939937e+00]
#  [4.12760090e+00]
#  [1.21383630e-02]
#  [4.08521607e+00]
#  [8.65328720e-01]
#  [1.88840329e+00]
#  [9.90428608e+00]
#  [5.94611293e+00]
#  [7.49518789e-01]
#  [2.71509572e+00]
#  [5.54568441e+00]
#  [3.83736988e+00]
#  [6.90310925e+00]
#  [5.47031663e+00]
#  [8.24304507e+00]
#  [4.38811452e+00]
#  [4.32562053e+00]
#  [3.53109327e+00]
#  [2.17509922e+00]
#  [6.81252894e+00]
#  [4.77304970e+00]
#  [1.30605384e+00]
#  [1.04810858e-01]
#  [3.76547887e-01]
#  [1.47196027e-01]
#  [1.95803619e+00]
#  [2.06399760e-02]
#  [6.25915329e+00]
#  [1.91504709e+00]
#  [3.29007982e+00]
#  [5.15906663e+00]
#  [1.46311817e+00]
#  [5.83825191e+00]
#  [3.14775140e+00]
#  [4.63311511e-01]
#  [3.11642848e+00]
#  [3.38512146e+00]
#  [1.22945417e+00]
#  [5.89516528e+00]
#  [1.86764612e+00]
#  [3.24666773e+00]
#  [4.36516669e+00]
#  [3.20650847e+00]
#  [2.50265302e+00]
#  [2.80732470e-02]
#  [1.63715750e+00]
#  [1.91093711e-01]
#  [6.49451786e+00]
#  [6.31290300e+00]
#  [5.70436037e+00]
#  [5.46317601e+00]
#  [5.73235814e-01]
#  [3.91894193e+00]
#  [5.40171533e+00]
#  [5.10641011e+00]
#  [4.95169721e-01]
#  [3.60835135e+00]
#  [2.81037534e+00]
#  [8.58645025e+00]
#  [5.96953804e+00]
#  [2.76135877e-01]
#  [4.66352678e+00]
#  [4.09139662e+00]
#  [3.04146875e+00]
#  [4.02001911e+00]
#  [3.38949957e+00]
#  [1.78471165e+00]
#  [4.15833882e+00]
#  [5.08955059e-01]
#  [2.79805324e+00]
#  [3.90985358e+00]
#  [2.97735659e-01]
#  [3.10355714e+00]
#  [4.43625964e+00]
#  [8.87423765e+00]
#  [4.06782199e+00]
#  [4.54266103e+00]
#  [5.48191524e+00]
#  [5.06610123e+00]
#  [1.25813206e-01]
#  [1.13631173e-01]
#  [2.32129586e+00]
#  [4.91233617e+00]
#  [5.27712439e+00]
#  [3.97207276e-01]
#  [1.86728813e+00]
#  [2.96320949e+00]
#  [3.87099190e+00]]

# %%
from sklearn.model_selection import train_test_split
x_trainsm,x_testsm,y_trainsm,y_testsm=train_test_split(Xsm,Ysm,test_size=0.2,random_state=0)

# %%
df.isnull().any()
# Out:
# Brand_name      False
# Year            False
# TV              False
# Radio           False
# Social Media    False
# Influencer      False
# Sponsering      False
# location        False
# Pre_Sales       False
# Aft_sales       False
# dtype: bool

# %%
model.fit(x_trainsm, y_trainsm)
# Out:
# LinearRegression()

# %%
#testing the model
y_predsm = model.predict(x_testsm)

# %%
#Finding the accuracy - How Accurate the model is?
import numpy as np
print("Mean Square Error(MSE): %.2f" % np.mean(((y_predsm - y_testsm)** 2)**0.5))
# Out:
# Mean Square Error(MSE): 2.15

# %%
print("Predicted value for training data:",model.score(x_trainsm,y_trainsm))
print("Training accuracy:",model.score(x_trainsm,y_trainsm)*100)
# Out:
# Predicted value for training data: 0.4873533917832692
# Training accuracy: 48.73533917832692

# %%
print("Predicted value for testing data:",model.score(x_testsm,y_testsm))
print("Testing accuracy:",model.score(x_testsm,y_testsm)*100)
# Out:
# Predicted value for testing data: -14.575874604634132
# Testing accuracy: -1457.5874604634132

# %% [markdown]
# Pre_Sales as dependent variable

# %%
df.head()
# Out:
#    Brand_name  Year    TV      Radio  Social Media  Influencer  Sponsering  \
# 0           0  2001  16.0   6.566231      2.907983        0.10         4.0
# 1           3  2001  13.0   9.237765      2.409567        0.23         2.0
# 2           2  2001  41.0  15.886446      2.913410        0.40        10.0
# 4           7  2001  15.0   8.437408      1.405998        0.03         6.0
# 5           8  2001  29.0   9.614382      1.027163        0.02        10.0
#
#    location   Pre_Sales  Aft_sales
# 0         1   54.732757    60.3224
# 1         0   46.677897    58.7690
# 2         0  150.177829   172.3340
# 4         0   56.594181    59.3420
# 5         1  105.889148   111.3240

# %%
Xps=np.array(df[['Brand_name','Year','TV','Radio','Social Media','Influencer','Sponsering','location','Aft_sales']])
Yps=np.array(df[['Pre_Sales']])

# %%
print(Xps)
# Out:
# [[0.000000e+00 2.001000e+03 1.600000e+01 ... 4.000000e+00 1.000000e+00
#   6.032240e+01]
#  [3.000000e+00 2.001000e+03 1.300000e+01 ... 2.000000e+00 0.000000e+00
#   5.876900e+01]
#  [2.000000e+00 2.001000e+03 4.100000e+01 ... 1.000000e+01 0.000000e+00
#   1.723340e+02]
#  ...
#  [9.000000e+00 2.009000e+03 7.700000e+01 ... 3.000000e+00 0.000000e+00
#   3.028864e+02]
#  [1.000000e+00 2.009000e+03 2.700000e+01 ... 3.000000e+00 0.000000e+00
#   1.019760e+02]
#  [6.000000e+00 2.009000e+03 7.700000e+01 ... 6.000000e+00 0.000000e+00
#   2.896640e+02]]

# %%
print(Yps)
# Out:
# [[ 54.73275715]
#  [ 46.67789698]
#  [150.1778288 ]
#  [ 56.5941808 ]
#  [105.8891476 ]
#  [108.7339319 ]
#  [270.1894    ]
#  [ 48.28058223]
#  [224.9610192 ]
#  [145.5439916 ]
#  [123.5261126 ]
#  [212.7643968 ]
#  [ 89.8199226 ]
#  [353.8046387 ]
#  [329.3505396 ]
#  [162.1913335 ]
#  [128.4846619 ]
#  [349.8615752 ]
#  [192.4619083 ]
#  [ 96.74937343]
#  [ 76.99292807]
#  [139.2887894 ]
#  [234.8510253 ]
#  [323.0321827 ]
#  [ 40.79219533]
#  [290.7775735 ]
#  [150.6264947 ]
#  [161.7851523 ]
#  [155.5991953 ]
#  [263.0206872 ]
#  [281.5789422 ]
#  [231.6700477 ]
#  [148.7069665 ]
#  [294.9524151 ]
#  [242.8248811 ]
#  [351.7730679 ]
#  [ 91.92229739]
#  [ 32.56682505]
#  [115.2625668 ]
#  [101.8731014 ]
#  [111.8997121 ]
#  [104.3526653 ]
#  [326.3817124 ]
#  [300.7305325 ]
#  [255.1551652 ]
#  [161.7170871 ]
#  [ 39.62567824]
#  [169.0081129 ]
#  [ 50.98848158]
#  [ 70.47172273]
#  [ 58.59009126]
#  [237.7721637 ]
#  [322.1004964 ]
#  [181.0796122 ]
#  [145.9192    ]
#  [228.5646491 ]
#  [288.9822393 ]
#  [ 49.81567405]
#  [299.099052  ]
#  [351.3598902 ]
#  [ 55.00971238]
#  [223.0991462 ]
#  [247.1394014 ]
#  [274.7071    ]
#  [289.1757587 ]
#  [168.0365387 ]
#  [198.3215216 ]
#  [349.7452965 ]
#  [166.1372196 ]
#  [ 59.28931563]
#  [272.6321364 ]
#  [ 77.41731834]
#  [349.4239745 ]
#  [127.0926738 ]
#  [ 43.06509252]
#  [336.5934202 ]
#  [345.3131637 ]
#  [154.2065565 ]
#  [304.7437748 ]
#  [335.2090696 ]
#  [104.1809671 ]
#  [112.269694  ]
#  [103.6348659 ]
#  [262.4011715 ]
#  [ 51.44298395]
#  [336.7606331 ]
#  [ 72.62590273]
#  [174.1981389 ]
#  [ 98.99963768]
#  [140.4152859 ]
#  [309.3616681 ]
#  [133.5654887 ]
#  [152.2546677 ]
#  [112.3081088 ]
#  [333.5791129 ]
#  [307.6190894 ]
#  [225.4862319 ]
#  [333.9664321 ]
#  [334.6459156 ]
#  [222.4683071 ]
#  [105.1853123 ]
#  [ 62.31766345]
#  [ 86.11553566]
#  [197.225133  ]
#  [143.8359148 ]
#  [263.105633  ]
#  [182.9860143 ]
#  [267.7373384 ]
#  [250.7513879 ]
#  [356.5821434 ]
#  [145.2164746 ]
#  [303.397391  ]
#  [132.3443679 ]
#  [104.5039262 ]
#  [174.5641128 ]
#  [ 96.43343282]
#  [104.1503565 ]
#  [354.7973747 ]
#  [ 80.94072509]
#  [131.1015188 ]
#  [135.5443199 ]
#  [ 49.18778559]
#  [141.3801238 ]
#  [119.3308074 ]
#  [321.0466894 ]
#  [240.4027581 ]
#  [226.9989318 ]
#  [341.4281402 ]
#  [335.3014311 ]
#  [273.9603772 ]
#  [249.3019048 ]
#  [117.0546557 ]
#  [208.7495053 ]
#  [106.0995933 ]
#  [243.0816632 ]
#  [156.9537519 ]
#  [ 61.70848657]
#  [299.3466037 ]
#  [222.4507601 ]
#  [ 82.54907175]
#  [144.5920869 ]
#  [234.021177  ]
#  [183.3277351 ]
#  [354.1039697 ]
#  [160.5796388 ]
#  [ 35.54799802]
#  [ 77.54794767]
#  [110.3748636 ]
#  [351.4266721 ]
#  [131.0772545 ]
#  [146.1456862 ]
#  [153.5822256 ]
#  [174.9861639 ]
#  [278.955153  ]
#  [178.3746767 ]
#  [197.0111372 ]
#  [261.0908818 ]
#  [204.099035  ]
#  [288.0207452 ]
#  [ 97.61236339]
#  [336.3726161 ]
#  [245.979961  ]
#  [334.643793  ]
#  [246.4947988 ]
#  [312.1429635 ]
#  [219.5681841 ]
#  [138.3753078 ]
#  [349.0483366 ]
#  [331.4840935 ]
#  [125.3870645 ]
#  [271.0264376 ]
#  [152.8312537 ]
#  [282.7480985 ]
#  [ 88.96782897]
#  [ 63.25378214]
#  [ 48.30375112]
#  [ 37.24327179]
#  [ 45.55251127]
#  [135.7731514 ]
#  [308.3930492 ]
#  [269.6030059 ]
#  [116.2374967 ]
#  [292.857168  ]
#  [135.5300789 ]
#  [325.5137107 ]
#  [357.1245732 ]
#  [334.0892379 ]
#  [ 97.50795879]
#  [191.6180402 ]
#  [256.4252258 ]
#  [279.5906387 ]
#  [209.8956538 ]
#  [159.6309441 ]
#  [290.0198478 ]
#  [170.1261872 ]
#  [ 78.81257166]
#  [277.0940713 ]
#  [ 51.15173712]
#  [275.8154126 ]
#  [225.791715  ]
#  [162.3039063 ]
#  [111.1277488 ]
#  [ 80.45443519]
#  [ 69.99070666]
#  [138.6769979 ]
#  [118.5011567 ]
#  [229.0903237 ]
#  [276.9190626 ]
#  [322.6677652 ]
#  [157.490072  ]
#  [ 56.81533661]
#  [139.792394  ]
#  [212.1691189 ]
#  [177.5025509 ]
#  [253.9861099 ]
#  [215.9054823 ]
#  [327.6536439 ]
#  [214.4576138 ]
#  [ 97.20055286]
#  [ 99.10933661]
#  [347.1547599 ]
#  [ 41.35123045]
#  [173.1550912 ]
#  [139.8343646 ]
#  [ 65.125304  ]
#  [152.9496029 ]
#  [270.6378511 ]
#  [303.6096465 ]
#  [248.0514829 ]
#  [239.7328932 ]
#  [162.1479537 ]
#  [167.5332259 ]
#  [343.7047069 ]
#  [222.4538087 ]
#  [229.5582512 ]
#  [269.0373261 ]
#  [ 42.65152205]
#  [263.5238127 ]
#  [296.2485996 ]
#  [ 46.84859882]
#  [322.4697556 ]
#  [312.3107698 ]
#  [123.9521411 ]
#  [320.5882954 ]
#  [188.8286445 ]
#  [ 55.33417257]
#  [342.6522282 ]
#  [ 84.70733843]
#  [333.0773697 ]
#  [188.1163762 ]
#  [ 98.16192205]
#  [ 47.50814092]
#  [294.4933353 ]
#  [231.9942926 ]
#  [ 62.0795245 ]
#  [304.9042152 ]
#  [220.7061299 ]
#  [225.469526  ]
#  [157.6872981 ]
#  [ 79.93998662]
#  [185.3102927 ]
#  [216.2681567 ]
#  [ 91.95954527]
#  [111.1431062 ]
#  [275.3886734 ]
#  [ 93.35175941]
#  [276.0838978 ]]

# %%
from sklearn.model_selection import train_test_split
x_trainps,x_testps,y_trainps,y_testps=train_test_split(Xps,Yps,test_size=0.2,random_state=0)

# %%
df.isnull().any()
# Out:
# Brand_name      False
# Year            False
# TV              False
# Radio           False
# Social Media    False
# Influencer      False
# Sponsering      False
# location        False
# Pre_Sales       False
# Aft_sales       False
# dtype: bool

# %%
model.fit(x_trainps, y_trainps)
# Out:
# LinearRegression()

# %%
#testing the model
y_predps = model.predict(x_testps)

# %%
#Finding the accuracy - How Accurate the model is?
import numpy as np
print("Mean Square Error(MSE): %.2f" % np.mean(((y_predps - y_testps)** 2)**0.5))
# Out:
# Mean Square Error(MSE): 2.81

# %%
print("Predicted value for training data:",model.score(x_trainps,y_trainps))
print("Training accuracy:",model.score(x_trainps,y_trainps)*100)
# Out:
# Predicted value for training data: 0.9991004715646015
# Training accuracy: 99.91004715646015

# %%
print("Predicted value for testing data:",model.score(x_testps,y_testps))
print("Testing accuracy:",model.score(x_testps,y_testps)*100)
# Out:
# Predicted value for testing data: 0.9970757628215625
# Testing accuracy: 99.70757628215625

# %% [markdown]
# Pre_Sales accurcy

# %%
accuracyps=model.score(Xps,Yps)*100
print(accuracyps)
# Out:
# 99.87348224544449
